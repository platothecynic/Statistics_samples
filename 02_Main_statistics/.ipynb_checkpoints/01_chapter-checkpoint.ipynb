# %% [markdown]
# # Основні теми статистики:

# %% [markdown]
# ## 3. Міри центральної тенденції

# %% [markdown]
# Мода - це найбільш часто зустрічаючесь значення ознаки яку вимірюємо

# %%
import numpy as np

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.default_rng().normal(mu, sigma, 10)

# %%
# Генеруємо дані
data = np.random.normal(165, 10, size=500).astype('int')

# %%
import matplotlib.pyplot as plt
import numpy as np
def hist_plot(data, n_bins):
    # Створюємо гістограму
    plt.hist(data, bins=20, edgecolor='black', alpha=0.7)

    # Налаштовуємо вигляд графіку
    plt.title('Гістограма')
    plt.xlabel('Значення')
    plt.ylabel('Частота')
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Відображаємо графік
    return plt.show()
hist_plot(data,20)

# %%
from scipy import stats as st
import numpy as np

st.mode(data, axis=0, nan_policy='propagate', keepdims=None)
# Out:
# /var/folders/dn/f65zy3pj4y9fm0d3kplg7n3r0000gn/T/ipykernel_72064/995204531.py:4: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   st.mode(data, axis=0, nan_policy='propagate', keepdims=None)
# ModeResult(mode=array([162]), count=array([24]))

# %% [markdown]
# Медіана - ділить впорядкований список даних на половину

# %%
np.median(data, axis=None, out=None, overwrite_input=False, keepdims=False)
# Out:
# 164.0

# %% [markdown]
# Середнє значення - це сума всіх значень в вибірці і поділити на їх кількість. Середнє значення вибірки позначається x̄ , а генеральної совокупності - &mu;

# %%
np.mean(data, axis=None, dtype=None, out=None)
# Out:
# 164.734

# %% [markdown]
# Для чого 3 міри центральної тенденції ? якщо всі 3 значення дуже близькі?

# %% [markdown]
# Коли наш розподіли симитричний, має одну моду і немає викидів, можна використовувати любу з трьох мір центральної тенденції. Бо всі три міри дадуть приблизно один і той ж самий результат

# %% [markdown]
# Але коли ми бачимо що в розподілі спостерігається асиметрія, тобто він скошений або вправо або в ліво або помітні викиди, або декілька мод, то використання середнього значення може дати нам некоректні результати, і краще використовувати моду або медіану.

# %% [markdown]
# ### Властивості середнього значення

# %% [markdown]
# 1. Якщо до кожного значення вибірки додати одне і теж число, то середнє значення теж збільшиться на це ж число M<sub>x+c</sub>=M<sub>x</sub> + с

# %%
import matplotlib.pyplot as plt
import numpy as np

# Збільшимо розмір фігури
plt.figure(figsize=(12, 5))

# Створюємо гістограму для оригінальних даних
plt.subplot(1, 2, 1)  # 1 рядок, 2 стовпця, перший графік
plt.hist(data, bins=20, edgecolor='black', alpha=0.7)

# Додаємо вертикальну лінію для середнього значення
mean_value = np.mean(data)
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=2, label=f'Середнє = {mean_value:.2f}')

# Налаштовуємо вигляд графіку
plt.title('Гістограма оригінальних даних')
plt.xlabel('Значення')
plt.ylabel('Частота')
plt.legend()  # Додаємо легенду

# Створюємо гістограму для даних з додаванням 10
plt.subplot(1, 2, 2)  # 1 рядок, 2 стовпця, другий графік
data_plus_10 = data + 10
plt.hist(data_plus_10, bins=20, edgecolor='black', alpha=0.7)

# Додаємо вертикальну лінію для середнього значення
mean_value = np.mean(data_plus_10)
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=2, label=f'Середнє = {mean_value:.2f}')

# Налаштовуємо вигляд графіку
plt.title('Гістограма даних з додаванням 10')
plt.xlabel('Значення')
plt.ylabel('Частота')
plt.legend()  # Додаємо легенду

# Відображаємо графіки
plt.tight_layout()
plt.show()

# %% [markdown]
# 2. Якщо кожне значення вибірки помножити одне і теж число, то середнє значення теж збільшиться у стільки ж разів M<sub>x*c</sub>=M<sub>x</sub> * с

# %%
import matplotlib.pyplot as plt
import numpy as np

# Збільшимо розмір фігури
plt.figure(figsize=(12, 5))

# Створюємо гістограму для оригінальних даних
plt.subplot(1, 2, 1)  # 1 рядок, 2 стовпця, перший графік
plt.hist(data, bins=20, edgecolor='black', alpha=0.7)

# Додаємо вертикальну лінію для середнього значення
mean_value = np.mean(data)
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=2, label=f'Середнє = {mean_value:.2f}')

# Налаштовуємо вигляд графіку
plt.title('Гістограма оригінальних даних')
plt.xlabel('Значення')
plt.ylabel('Частота')
plt.legend()  # Додаємо легенду

# Створюємо гістограму для даних з додаванням 10
plt.subplot(1, 2, 2)  # 1 рядок, 2 стовпця, другий графік
data_multiply_10 = data * 10
plt.hist(data_multiply_10, bins=20, edgecolor='black', alpha=0.7)

# Додаємо вертикальну лінію для середнього значення
mean_value = np.mean(data_multiply_10)
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=2, label=f'Середнє = {mean_value:.2f}')

# Налаштовуємо вигляд графіку
plt.title('Гістограма даних з множенням всіх значень в вибірці на 10')
plt.xlabel('Значення')
plt.ylabel('Частота')
plt.legend()  # Додаємо легенду

# Відображаємо графіки
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. якщо від середнього значення відняти кожне значення нашої вибірки і просумувати то отримаємо 0

# %%
mean_ = np.mean(data)
lst = []
for number in data:
    
    lst.append(mean_ - number)
sum(lst)
# Out:
# 4.433786671143025e-12

# %% [markdown]
# ## 4. Міри мінливості

# %% [markdown]
# 1. Розмах - різниця між максимальним і мінімальним значенням в вибірці. Недоліки: зміна одного з крайніх значень, буде дуже сильно змінювати значення розмаху

# %%
np.ptp(data, axis=None, out=None)
# Out:
# 61

# %% [markdown]
# 2. Дисперсія показує наскільки в середньому всі наші значення в вибірці відрізняються від середнього значення в вибірці. D= Середньому квадрату відхилень відхилень від середнього.
#
# Квадрат потрібен для того щоб сума всіх відхилень від середнього != 0.

# %%
np.var(data, axis=None, dtype=None, out=None, ddof=0)
# Out:
# 105.29524400000001

# %%
def calculate_variance(data):
    N = len(data)
    
    # Розрахунок середнього значення
    mean = sum(data) / N
    
    # Розрахунок суми квадратів відхилень від середнього
    sum_squared_diff = sum((x - mean) ** 2 for x in data)
    
    # Розрахунок дисперсії
    variance = sum_squared_diff / N
    
    return variance

# Приклад використання
result = calculate_variance(data)
print("Дисперсія:", result)
# Out:
# Дисперсія: 105.29524399999997

# %%
np.var(data, axis=None, dtype=None, out=None, ddof=1)
# Out:
# 105.50625651302606

# %% [markdown]
# 3. Корінь з дисперсії це середнє квадратичне відхилення. Воно показує реальне відхилення в вибірці, навідміну від дисперсії

# %%
np.sqrt(106.4421760000007)
# Out:
# 10.317081757939146

# %%
np.std(data, axis=None, dtype=None, out=None, ddof=0)
# Out:
# 10.26134708505662

# %% [markdown]
# &sigma; - середнє квадратичне відхилення для ГС, а sd - для вибірки.
# І Значення sd показує що в середньому кожен елемент нашої вибірки відхиляється на це число від середнього

# %%
std_population = np.std(data, ddof=0)
print("Стандартне відхилення для ГС:", std_population)
# Out:
# Стандартне відхилення для ГС: 10.26134708505662

# %%
std_sample = np.std(data, ddof=1)
print("Вибіркове стандартне відхилення:", std_sample)
# Out:
# Вибіркове стандартне відхилення: 10.271623849860648

# %% [markdown]
# Дисперсія для вибірки потрібно в формулі зробити n-1

# %%
l = [1, 2, 2, 3, 4, 4, 5]
np.mean(l)
# Out:
# 3.0

# %%
for numb in l:
    print(np.mean(l) - numb)
# Out:
# 2.0
# 1.0
# 1.0
# 0.0
# -1.0
# -1.0
# -2.0

# %%
l1 = []
for numb in l:
    l1.append(np.mean(l) - numb)
l1
# Out:
# [2.0, 1.0, 1.0, 0.0, -1.0, -1.0, -2.0]

# %%
np.sum(l1)
# Out:
# 0.0

# %%
[x**2 for x in l1]
# Out:
# [4.0, 1.0, 1.0, 0.0, 1.0, 1.0, 4.0]

# %%
np.sum([x**2 for x in l1])
# Out:
# 12.0

# %%
np.sum([x**2 for x in l1])/len(l1)
# Out:
# 1.7142857142857142

# %%
D = np.sum([x**2 for x in l1])/(len(l1)-1)

# %%
std = np.sqrt(D)
std
# Out:
# 1.4142135623730951

# %% [markdown]
# ### 2 важливі властивості дисперсії і std

# %% [markdown]
# 1. Якщо до кожного спостереження нащої вибірки додати якесь число, дисперсія не зміниться і std теж
# ![image.png](attachment:image.png)

# %%
data_plus_ten = data + 10

# %%
np.var(data, axis=None, dtype=None, out=None, ddof=1)
# Out:
# 105.50625651302606

# %%
np.var(data_plus_ten, axis=None, dtype=None, out=None, ddof=1)
# Out:
# 105.50625651302606

# %%
 np.std(data, ddof=1)
# Out:
# 10.271623849860648

# %%
 np.std(data_plus_ten, ddof=1)
# Out:
# 10.271623849860648

# %% [markdown]
# 2. Якщо кожне спостереження вибіркі помножити на якесь число
# то std * c , а D * c2
#
# ![image.png](attachment:image.png)

# %%
data_multyply_ten = data * 10

# %%
np.var(data, axis=None, dtype=None, out=None, ddof=1)
# Out:
# 105.50625651302606

# %%
np.var(data_multyply_ten, axis=None, dtype=None, out=None, ddof=1)
# Out:
# 10550.625651302606

# %%
 np.std(data, ddof=1)
# Out:
# 10.271623849860648

# %%
 np.std(data_multyply_ten, ddof=1)
# Out:
# 102.71623849860647

# %% [markdown]
# ## Квартилі

# %%
data
# Out:
# array([162, 162, 162, 144, 183, 153, 162, 150, 167, 177, 153, 155, 154,
#        163, 190, 168, 175, 149, 156, 154, 148, 164, 153, 180, 144, 176,
#        154, 164, 173, 165, 176, 172, 172, 163, 169, 159, 173, 164, 197,
#        170, 169, 190, 172, 182, 157, 169, 181, 155, 182, 160, 175, 164,
#        159, 172, 162, 177, 183, 188, 178, 158, 152, 168, 151, 170, 167,
#        158, 172, 175, 150, 151, 155, 152, 172, 152, 163, 173, 169, 151,
#        181, 160, 161, 171, 164, 165, 167, 151, 157, 164, 193, 160, 167,
#        166, 157, 165, 165, 160, 170, 170, 165, 164, 173, 180, 159, 164,
#        176, 167, 151, 172, 180, 167, 154, 166, 172, 154, 154, 155, 170,
#        171, 181, 173, 168, 158, 152, 169, 179, 177, 168, 164, 173, 151,
#        161, 148, 164, 169, 163, 175, 175, 155, 163, 172, 156, 180, 164,
#        136, 172, 160, 164, 168, 177, 166, 159, 165, 162, 164, 175, 170,
#        152, 171, 171, 167, 153, 149, 161, 152, 150, 162, 169, 163, 175,
#        150, 159, 173, 165, 145, 157, 163, 162, 175, 170, 169, 154, 165,
#        166, 173, 160, 154, 164, 165, 164, 156, 178, 174, 176, 160, 159,
#        154, 173, 163, 160, 161, 160, 173, 186, 156, 157, 168, 173, 154,
#        175, 170, 167, 147, 167, 158, 156, 185, 176, 163, 160, 168, 188,
#        168, 179, 170, 156, 169, 165, 184, 158, 157, 145, 160, 165, 145,
#        163, 164, 172, 152, 179, 170, 169, 175, 175, 176, 157, 192, 175,
#        167, 175, 169, 165, 192, 174, 188, 154, 144, 164, 162, 161, 155,
#        153, 167, 146, 167, 158, 150, 162, 167, 164, 154, 167, 174, 166,
#        178, 150, 173, 172, 156, 162, 162, 173, 160, 162, 142, 163, 156,
#        148, 158, 164, 160, 156, 161, 164, 151, 172, 173, 158, 162, 176,
#        167, 172, 162, 160, 151, 167, 168, 147, 162, 161, 161, 172, 156,
#        166, 167, 144, 177, 159, 177, 151, 178, 163, 168, 191, 159, 159,
#        185, 180, 178, 161, 168, 149, 163, 163, 146, 166, 148, 170, 168,
#        167, 170, 174, 164, 145, 149, 148, 165, 166, 176, 157, 159, 163,
#        155, 162, 152, 171, 182, 162, 176, 177, 158, 162, 171, 175, 182,
#        174, 150, 150, 164, 150, 186, 150, 163, 160, 156, 173, 171, 155,
#        157, 148, 163, 167, 152, 153, 163, 168, 163, 166, 172, 147, 154,
#        163, 156, 161, 161, 175, 165, 158, 153, 144, 166, 163, 185, 146,
#        144, 160, 158, 174, 158, 162, 184, 161, 151, 175, 171, 157, 171,
#        158, 170, 181, 157, 156, 166, 161, 171, 162, 147, 166, 169, 167,
#        163, 167, 174, 159, 175, 180, 149, 173, 171, 171, 171, 156, 175,
#        175, 157, 159, 172, 162, 160, 153, 162, 152, 176, 160, 174, 147,
#        187, 153, 149, 171, 172, 184, 180, 170, 174, 158, 172, 158, 183,
#        176, 188, 168, 158, 156, 157, 156, 171, 176, 173, 168, 174, 168,
#        171, 170, 161, 159, 170, 173, 161, 170, 162, 156, 188, 171, 159,
#        148, 169, 152, 173, 160, 156])

# %%
import plotly.express as px
import pandas as pd
df = pd.DataFrame(data)
fig = px.box(df, y=0, points='all')
fig.show('iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_65.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
